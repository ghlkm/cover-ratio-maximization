# %%
import numpy as np
import random as r
uniform_=r.uniform
gauss_=r.gauss
def uniform(a=0, b=1):
    return uniform_(a, b)
def gauss():
    ret=-1
    while ret<0 or ret>1:
        ret=gauss_(.5, 0.15)
    return ret

def dot6(nums):
    nums*=10**6
    nums=np.floor(nums)
    nums/=10**6
    return nums
def norm(data):
    for i in range(len(data[0])):
        dmin=min(data[:, i])
        dmax=max(data[:, i])
        dd=dmax-dmin
        data[:,i]-=dmin
        data[:, i]/=dd
    return data
def dot6_norm(data):
    data=dot6(data)
    data=norm(data)
    return data

# %%
def sample_point_uni(d, b=1.0):
    left=b
    ret=[]
    for i in range(d-1):
        tmp=(1-(uniform(0, 1))**(1/(d-i-1)))
        ret.append(left*tmp)
        left-=ret[-1]
    ret.append(left)
    return ret
def gen_user_uni(n, d):
    ret =[sample_point_uni(d) for _ in range(n)]
    return ret
def gen_pdt_uni(n, d):
    ret=[]
    for i in range(n):
        ret.append([uniform() for _ in range(d)])
    return ret
def gen_pdt_anti(n, d):
#     ret =[sample_point_uni(d) for _ in range(n)]
    # TODO more than 2 dimension
    means=[.5, .5]
    cov=[[1, -.95], [-.95, 1]]
    ret=np.random.multivariate_normal(means, cov, n)
    for i in range(d):
        dmin=min(ret[:, i])
        dmax=max(ret[:, i])
        ret[:,i]-=dmin
        ret[:,i]/=(dmax-dmin)
    return ret
def gen_pdt_corr(n, d):
    mean=[.5 for _ in range(d)]
    cov=[]
    for i in range(d):
        tmp=[]
        for j in range(d):
            if i==j:
                tmp.append(1)
            else:
                tmp.append(.95)
        cov.append(tmp)
    data = np.random.multivariate_normal(mean, cov, n)
    data=dot6_norm(data)
    return data

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_user(user, save=False, fn='', format='eps'):
    fig, ax = plt.subplots()
    user_a = np.array(user).T
    ax.scatter(user_a[0], user_a[1])
    ax.set(xlim=(0, 1), ylim=(0, 1))
    ax.set_aspect('equal', 'box')
    ax.set_xlabel('p[1]')
    ax.set_ylabel('p[2]')
    if save:
        plt.savefig(fn + '.'+format, format=format, bbox_inches='tight')
        plot_user(user)
    else:
        plt.show()


def plot_pdt(pdt, save=False, fn='', format='eps'):
    plot_user(pdt, save, fn, format)


def plot_halfspace(r, c, save=False, fn='', format='eps'):
    fig, ax = plt.subplots()
    ax.set_xlabel('p[1]')
    ax.set_ylabel('p[2]')
    ax.set(xlim=(0, 1), ylim=(0, 1))
    ax.set_aspect('equal', 'box')
    for i in range(len(r)):
        row = r[i]
        if row[0] == 0 or row[1] == 0:
            continue
        ax.plot([c[i] / row[0], 0], [0, c[i] / row[1]])
    if save:
        plt.savefig(fn + '.'+format, format=format, bbox_inches='tight')
        plot_halfspace(r, c)
    else:
        plt.show()


def plot_pdt_hs(pdt, pdt_p, pdt_c, r, c, covered=set(), save=False, fn='', format='eps'):
    fig, ax = plt.subplots()
    ax.set(xlim=(0, 1), ylim=(0, 1))
    ax.set_aspect('equal', 'box')
    ax.set_xlabel('p[1]')
    ax.set_ylabel('p[2]')
    for i in range(len(r)):
        row = r[i]
        if row[0] == 0 or row[1] == 0:
            continue
        if i in covered:
            ax.plot([c[i] / row[0], 0], [0, c[i] / row[1]], alpha=0.2, c='cyan')
        else:
            ax.plot([c[i] / row[0], 0], [0, c[i] / row[1]],  alpha=0.2, c='orange')
    pdtT = pdt.T
    ax.scatter(pdtT[0], pdtT[1], c='grey', s=10)
    ax.scatter(pdt[pdt_p, 0], pdt[pdt_p, 1], c='blue', s=10)
    ax.scatter(pdt[pdt_c, 0], pdt[pdt_c, 1], c='red', s=30)
    if save:
        plt.savefig(fn + '.'+format, format=format, bbox_inches='tight')
        plot_pdt_hs(pdt, pdt_p, pdt_c, r, c, covered)
    else:
        plt.show()


def plot_pdt_inter_hs(r, c, cost, B, inter=set(), save=False, fn='', format='eps'):
    fig, ax = plt.subplots()
    ax.set_xlabel('p[1]')
    ax.set_ylabel('p[2]')
    ax.set(xlim=(0, 1), ylim=(0, 1))
    ax.set_aspect('equal', 'box')
    ax.plot([B / cost[0], 0], [0, B / cost[1]], c='black', linewidth=3)
    for i in range(len(r)):
        row = r[i]
        if row[0] == 0 or row[1] == 0:
            continue
        if i in inter:
            ax.plot([c[i] / row[0], 0], [0, c[i] / row[1]], alpha=0.3, c='orange')
        else:
            ax.plot([c[i] / row[0], 0], [0, c[i] / row[1]], alpha=0.3, c='cyan')
    if save:
        plt.savefig(fn + '.'+format, format=format, bbox_inches='tight')
        plot_pdt_inter_hs(r, c, cost, B, inter)
    else:
        plt.show()


def plot_inters(inter_cnt, save=False, fn='', format='eps'):
    fig, ax = plt.subplots()
    ax.set_xlabel('B')
    ax.set_ylabel('Intersect halfspaces')
    tmp = np.array(inter_cnt).T
    x = [1 + i / 10 for i in range(10)]
    labels = ['uniform', 'anti', 'corr']
    style = ['bo-', 'y^-', 'rP-']

    for i in range(tmp.shape[0]):
        ax.plot(x, tmp[i], style[i], label=labels[i], mfc='none')
    # ax.set_yscale('log')
    ax.legend()
    if save:
        plt.savefig(fn + '.'+format, format=format)
        plot_inters(inter_cnt, save=False)
    else:
        plt.show()

# %%
def get_sk(user, pdt, k):
    pdtT=pdt.T
    sk=np.zeros(len(user))
    for uid in range(len(user)):
        scores = np.dot(user[uid],pdtT)
        scores = sorted(scores, reverse=True)
        sk[uid]=scores[k]
    return sk
def sampleP(cardD, cardP):
    return r.sample(range(cardD), cardP)
from scipy.optimize import linprog
def feasible(user, sk, A, bs, hp,  gt, cr, c):
    target=[1, 1]
    x0_bounds = (0, 1)
    x1_bounds = (0, 1)
    try:
        if gt:
            bs.append(-sk[hp])
        else:
            bs.append(sk[hp])
        bs.append(c)
        if gt:
            A.append([-i for i in user[hp]])
        else:
            A.append(user[hp])
        A.append(cr)
        res=linprog(target, A_ub=A, b_ub=bs, 
                    bounds=(x0_bounds, x1_bounds), options={"disp": False})
        bs.pop()
        bs.pop()
        A.pop()
        A.pop()
        return res.success
    except:
        bs.pop()
        bs.pop()
        A.pop()
        A.pop()
        print("fail linprog")
        return False

# %%
class Cell:
    def __init__(self):
        self.left=None
        self.right=None
        self.hp=[]  # [id, bool] le=0, gt=1
        self.neg_HP=0
        self.pruned=False
        self.pos_HP=[]
    def __init__(self, nt=0, side=False):
        self.left=None
        self.right=None
        self.hp=[nt, side]  # [id, bool] le=0, gt=1
        self.neg_HP=0
        self.pruned=False
        self.pos_HP=[]
    def __del__(self):
        if self.left:
            del(self.left)
            self.left=None
        if self.right:
            del(self.right)
            self.right=None

# %%
cardD=1000
cardW=100
d=2
user=gen_user_uni(cardW, d)
pdt_uni=gen_pdt_uni(cardD, d)
pdt_anti=gen_pdt_anti(cardD, d)
pdt_corr=gen_pdt_corr(cardD, d)
# plot_user(user)
# plot_pdt(pdt_uni)
# plot_pdt(pdt_anti)
# plot_pdt(pdt_corr)
k=2
user=np.array(user)
pdt_uni=np.array(pdt_uni)
pdt_anti=np.array(pdt_anti)
pdt_corr=np.array(pdt_corr)
sk_uni=get_sk(user, pdt_uni, k)
sk_anti=get_sk(user, pdt_anti, k)
sk_corr=get_sk(user, pdt_corr, k)
print(sk_anti)
prunk=10**6
cell_cnt=0
def inserthp_dfs(node, user, sk, A, bs, order, pos, neg, cr, c):
    global prunk
    global cell_cnt
    if prunk<neg:
        return
    order2=[]
    for i1 in order:
        if not feasible(user, sk, A, bs, i1, False, cr, c):
            node.pos_HP.append(i1)
            pos+=1
        elif not feasible(user, sk, A, bs, i1, True, cr, c):
            neg+=1
            if neg > prunk:
                return
        else:
            order2.append(i1)
    if len(order2)==0:
        if neg<=prunk:
            prunk=neg
            print(prunk, ",", pos)
        return 
    nt=order2.pop()
    cell_cnt+=2
    node.left=Cell(nt, True)
    node.right=Cell(nt, False)
    poshp_pos=pos+1
    poshp_neg=neg
    neghp_pos=pos
    neghp_neg=neg+1
    A.append([-i for i in user[nt]])
    bs.append(-sk[nt])
    inserthp_dfs(node.left, user, sk, A, bs, order2, poshp_pos, poshp_neg, cr, c)
    A.pop()
    bs.pop()
    
    A.append(user[nt])
    bs.append(sk[nt])
    inserthp_dfs(node.right, user, sk, A, bs, order2, neghp_pos, neghp_neg, cr, c)
    A.pop()
    bs.pop()

def insert_dfs(root, user, sk, cr, c):
    A=[]
    bs=[]
    order=[i for i in range(cardW)]
    inserthp_dfs(root, user, sk, A, bs, order, 0, 0, cr, c)
import time
rt=Cell()
tmp=time.time()
insert_dfs(rt, user, sk_anti, [1, 1], 1.25)
print(time.time()-tmp)
# Out:
# [0.81219362 0.83478003 0.7070202  0.64234523 0.57063516 0.66902289
#  0.61690882 0.74252917 0.69366566 0.74039963 0.59174826 0.8067087
#  0.68108149 0.70654034 0.61020939 0.69509484 0.77952758 0.6075762
#  0.82688796 0.6245537  0.78850687 0.77171865 0.57770684 0.5720656
#  0.84116701 0.75472891 0.67904393 0.80627758 0.55771509 0.5722541
#  0.65478835 0.7070956  0.56949784 0.60733487 0.80486867 0.56285529
#  0.71295733 0.67078462 0.79650157 0.68391282 0.82098153 0.75441585
#  0.71233743 0.8073885  0.66593926 0.61274261 0.55783174 0.60455727
#  0.77822949 0.7961159  0.67935828 0.79433376 0.78065683 0.64187256
#  0.66893809 0.72724575 0.76849358 0.81162116 0.74750464 0.61992615
#  0.55786603 0.72820901 0.64573219 0.80160268 0.68653777 0.67823814
#  0.82916642 0.66556918 0.80765309 0.59679331 0.77927237 0.59519697
#  0.68547207 0.67139566 0.58712503 0.74639263 0.78571968 0.56373774
#  0.66002679 0.56895604 0.70724685 0.580968   0.70852414 0.55787717
#  0.56741901 0.73669772 0.64378718 0.85363195 0.62547717 0.60492788
#  0.69251778 0.73315622 0.81207944 0.68952986 0.57545037 0.55764848
#  0.65702354 0.63805988 0.67021825 0.77670401]
# fail linprog
# fail linprog
# 41 , 59
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\ipykernel_launcher.py:28: OptimizeWarning: Solving system with option 'cholesky':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'cholesky' to False.
# C:\anacondaanzhuang\lib\site-packages\ipykernel_launcher.py:28: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.94323e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.39597e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.84676e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.29153e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.35318e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.69487e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.82837e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.21403e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.50608e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# fail linprog
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.21603e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.41033e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.81442e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.91533e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.27083e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.09465e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.9952e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=8.21797e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.24555e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.82242e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.29094e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.67166e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.32146e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# fail linprog
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.03347e-21): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.21372e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=8.08996e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.98118e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.46766e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.59573e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=6.00936e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.47953e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.55041e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.87602e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.64161e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.743e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.77305e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.7676e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.94453e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.29128e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.46168e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# fail linprog
# fail linprog
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.99028e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.3894e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.05538e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.88719e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.02396e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.03095e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=8.92688e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.75251e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.34253e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.72239e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.0441e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.55823e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=8.9452e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.3755e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.2242e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.21116e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.88345e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.08086e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.71656e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.99995e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.43244e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.92603e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.29176e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.79374e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.95158e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.58606e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.71865e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.76583e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=3.15242e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=6.37421e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.65e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.26937e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=6.50822e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.70208e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.18717e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.55233e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.68804e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=6.15526e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.14784e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.16134e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.69487e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.65833e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.36159e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.34066e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.00526e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.77257e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.02187e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=7.26054e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=8.22898e-20): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.50797e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.0273e-17): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.56737e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.34117e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=9.69606e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.97914e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.5972e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=1.1861e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.31432e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# fail linprog
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=5.93085e-19): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=6.09687e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=4.64051e-29): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# 37.350340843200684
# C:\anacondaanzhuang\lib\site-packages\scipy\optimize\_linprog_ip.py:110: LinAlgWarning: Ill-conditioned matrix (rcond=2.43671e-18): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)

# %%
class test:
    pass
t=test()
del(t)
t=None
